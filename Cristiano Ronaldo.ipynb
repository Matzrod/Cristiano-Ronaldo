# %% [markdown]
# # Análise de Aprendizado do Curso da Universidade de Dados

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('data.csv')

# %% [markdown]
# # Dados Básicos

# %%
df.head()
# Out:
#    Unnamed: 0  Goal_no Season                Competition      Matchday Venue  \
# 0           0        1    2/3              Liga Portugal             6     H
# 1           1        2    2/3              Liga Portugal             6     H
# 2           2        3    2/3              Liga Portugal             8     A
# 3           3        4    2/3  TaÃ§a de Portugal Placard  Fourth Round     H
# 4           4        5    2/3  TaÃ§a de Portugal Placard   Fifth Round     H
#
#           Team                 Opponent Result Position Minute At_score  \
# 0  Sporting CP            Moreirense FC    3:0       LW     34      2:0
# 1  Sporting CP            Moreirense FC    3:0      NaN   90+5      3:0
# 2  Sporting CP              Boavista FC    1:2      NaN     88      1:2
# 3  Sporting CP             CD Estarreja    4:1      NaN     67      3:0
# 4  Sporting CP  FC Oliveira do Hospital    8:1      NaN     13      3:0
#
#         Type_of_goal
# 0           Solo run
# 1             Header
# 2  Right-footed shot
# 3   Left-footed shot
# 4                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    698 non-null    int64
#  1   Goal_no       698 non-null    int64
#  2   Season        698 non-null    object
#  3   Competition   698 non-null    object
#  4   Matchday      698 non-null    object
#  5   Venue         698 non-null    object
#  6   Team          698 non-null    object
#  7   Opponent      698 non-null    object
#  8   Result        698 non-null    object
#  9   Position      640 non-null    object
#  10  Minute        698 non-null    object
#  11  At_score      698 non-null    object
#  12  Type_of_goal  683 non-null    object
# dtypes: int64(2), object(11)
# memory usage: 71.0+ KB

# %%
df.shape
# Out:
# (698, 13)

# %%
print("Temos %0.f linhas e %0.f colunas"%(df.shape[0], df.shape[1]))
# Out:
# Temos 698 linhas e 13 colunas

# %%
df.index
# Out:
# RangeIndex(start=0, stop=698, step=1)

# %% [markdown]
# # Análise de Dados Exploratórios

# %% [markdown]
# # Gols por Competição

# %%
sns.set(rc={'figure.figsize':(15,3)})
plt.xticks(fontsize=15,rotation='vertical')
p=sns.countplot(df['Competition'],hue_order=df.groupby('Competition'))
p.axes.set_title("Goals por Competição",fontsize=30)
# Out:
# C:\Users\matheus.abreu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Goals por Competição')

# %% [markdown]
# # Gols por Temporada

# %%
sns.set(rc={'figure.figsize':(10,5)})
plt.xticks(fontsize=15,rotation='vertical')
p=sns.countplot(df['Season'],hue_order=df.groupby('Competition'))
p.axes.set_title("Gols por Temporada",fontsize=30)
;
# Out:
# C:\Users\matheus.abreu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ''

# %% [markdown]
# # Gols por Clube

# %%
sns.set(rc={'figure.figsize':(10,5)})
plt.xticks(fontsize=15,rotation='vertical')
p=sns.countplot(df['Team'],hue_order=df.groupby('Competition'))
p.axes.set_title("Gols por Clube",fontsize=30)
# Out:
# C:\Users\matheus.abreu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gols por Clube')

# %% [markdown]
# # Gols por posição em que atuou

# %% [markdown]
# - Legenda:
# -RW = Right Winger – Ala Direito.
# -LW = Left Winger – Ala Esquerdo.
# -LF = Left Forward – Atacante Esquerdo.
# -RF = Right Forward – Atacante Direito.

# %%
sns.set(rc={'figure.figsize':(10,5)})
plt.xticks(fontsize=15,rotation='vertical')
p=sns.countplot(df['Position'],hue_order=df.groupby('Competition'))
p.axes.set_title("Goals per Position",fontsize=30)
# Out:
# C:\Users\matheus.abreu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Goals per Position')

# %% [markdown]
# # Gols por Minuto

# %%
mins=list(map(str, range(1,120)))
for min in df['Minute']:
    if min not in mins:
        mins.append(min)
mins1=mins[:int(len(mins)/5)]
mins2=mins[int(len(mins)/5):int(2*len(mins)/5)]
mins3=mins[2*int(len(mins)/5):int(3*len(mins)/5)]
mins4=mins[3*int(len(mins)/5):int(4*len(mins)/5)]
mins5=mins[int(4*len(mins)/5):]

# %%
sns.set(rc={'figure.figsize':(20,5)})
plt.xticks(fontsize=10)
p=sns.countplot(df['Minute'],order=mins1)
p.axes.set_title("Gols por Minuto (1-26)",fontsize=30)
# Out:
# C:\Users\matheus.abreu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gols por Minuto (1-26)')

# %%
p=sns.countplot(df['Minute'],order=mins2)
p.axes.set_title("Gols por Minuto (27-52)",fontsize=30)
# Out:
# C:\Users\matheus.abreu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gols por Minuto (27-52)')

# %%
p=sns.countplot(df['Minute'],order=mins3)
p.axes.set_title("Gols por Minuto (53-78)",fontsize=30)
# Out:
# C:\Users\matheus.abreu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gols por Minuto (53-78)')

# %%
p=sns.countplot(df['Minute'],order=mins4)
p.axes.set_title("Gols por Minuto (79-104)",fontsize=30)
# Out:
# C:\Users\matheus.abreu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gols por Minuto (79-104)')

# %%
p=sns.countplot(df['Minute'],order=mins5)
p.axes.set_title("Gols por Minuto (104-Extra)",fontsize=30)
# Out:
# C:\Users\matheus.abreu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gols por Minuto (104-Extra)')

# %% [markdown]
# # Gols por Tipo de Gol

# %%
sns.set(rc={'figure.figsize':(10,4)})
plt.xticks(fontsize=15,rotation='vertical')
p=sns.countplot(df['Type_of_goal'],hue_order=df.groupby('Competition'))
p.axes.set_title("Gols por Tipo de Gol",fontsize=30)
# Out:
# C:\Users\matheus.abreu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gols por Tipo de Gol')

# %% [markdown]
# # Resultado Após o Gol

# %%
sns.set(rc={'figure.figsize':(10,5)})
plt.xticks(fontsize=15,rotation='vertical')
p=sns.countplot(df['At_score'],hue_order=df.groupby('Competition'))
p.axes.set_title("Resultado após o gol",fontsize=30)
# Out:
# C:\Users\matheus.abreu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Resultado após o gol')

# %% [markdown]
# # Gols por Oponente

# %%
sns.set(rc={'figure.figsize':(30,5)})
plt.xticks(fontsize=10,rotation='vertical')
p=sns.countplot(df['Opponent'],hue_order=df.groupby('Competition'))
p.axes.set_title("Gols por Oponente",fontsize=30)
# Out:
# C:\Users\matheus.abreu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gols por Oponente')

# %% [markdown]
# # Oponentes Favoritos

# %%
sns.set(rc={'figure.figsize':(12,5)})
opponents_df=df.groupby('Opponent').size().reset_index(name='count')
fav_opponents_df=opponents_df[opponents_df["count"]>15]
plt.bar(x=fav_opponents_df['Opponent'],height=fav_opponents_df['count'],color="#1a55e7")
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# # Gols em casa e Fora de casa

# %% [markdown]
# H = Home, A = Away

# %%
sns.set(rc={'figure.figsize':(3,3)})
plt.xticks(fontsize=15)
p=sns.countplot(df['Venue'],hue_order=df.groupby('Competition'))
p.axes.set_title("Gols por Locais(Casa/Fora)",fontsize=20)
# Out:
# C:\Users\matheus.abreu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gols por Locais(Casa/Fora)')
